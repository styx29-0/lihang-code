# %% [markdown]
# # 第1章 统计学习方法概论

# %% [markdown]
# 1．统计学习是关于计算机基于数据构建概率统计模型并运用模型对数据进行分析与预测的一门学科。统计学习包括监督学习、非监督学习、半监督学习和强化学习。
#
# 2．统计学习方法三要素——模型、策略、算法，对理解统计学习方法起到提纲挈领的作用。
#
# 3．本书主要讨论监督学习，监督学习可以概括如下：从给定有限的训练数据出发， 假设数据是独立同分布的，而且假设模型属于某个假设空间，应用某一评价准则，从假设空间中选取一个最优的模型，使它对已给训练数据及未知测试数据在给定评价标准意义下有最准确的预测。
#
# 4．统计学习中，进行模型选择或者说提高学习的泛化能力是一个重要问题。如果只考虑减少训练误差，就可能产生过拟合现象。模型选择的方法有正则化与交叉验证。学习方法泛化能力的分析是统计学习理论研究的重要课题。
#
# 5．分类问题、标注问题和回归问题都是监督学习的重要问题。本书中介绍的统计学习方法包括感知机、$k$近邻法、朴素贝叶斯法、决策树、逻辑斯谛回归与最大熵模型、支持向量机、提升方法、EM算法、隐马尔可夫模型和条件随机场。这些方法是主要的分类、标注以及回归方法。它们又可以归类为生成方法与判别方法。

# %% [markdown]
# ### 使用最小二乘法拟和曲线
#
# 高斯于1823年在误差$e_1,…,e_n$独立同分布的假定下,证明了最小二乘方法的一个最优性质: 在所有无偏的线性估计类中,最小二乘方法是其中方差最小的！
# 对于数据$(x_i, y_i)   (i=1, 2, 3...,m)$
#
# 拟合出函数$h(x)$
#
# 有误差，即残差：$r_i=h(x_i)-y_i$
#
# 此时$L2$范数(残差平方和)最小时，$h(x)$ 和 $y$ 相似度最高，更拟合

# %% [markdown]
# 一般的$H(x)$为$n$次的多项式，$H(x)=w_0+w_1x+w_2x^2+...w_nx^n$
#
# $w(w_0,w_1,w_2,...,w_n)$为参数
#
# 最小二乘法就是要找到一组 $w(w_0,w_1,w_2,...,w_n)$ ，使得$\sum_{i=1}^n(h(x_i)-y_i)^2$ (残差平方和) 最小
#
# 即，求 $min\sum_{i=1}^n(h(x_i)-y_i)^2$
#
# ----

# %% [markdown]
# 举例：我们用目标函数$y=sin2{\pi}x$, 加上一个正态分布的噪音干扰，用多项式去拟合【例1.1 11页】

# %%
import numpy as np  #导入numpy这个Python库，并将其命名为np。这样在后续使用numpy的函数和方法时，可以直接调用np来代替numpy。
import scipy as sp  #导入scipy这个Python库，并将其命名为sp。这样在后续使用scipy的函数和方法时，可以直接调用sp来代替scipy。
from scipy.optimize import leastsq
#scipy.optimize是Python的scipy库中提供的优化模块，包含了很多常用的数值优化算法。这些算法可以求解最小化或最大化目标函数、参数估计、曲线拟合、求解方程等各种问题。
#从Python的scipy库中导入leastsq函数。leastsq是一个用于非线性最小二乘拟合的函数，可用于求解参数估计或拟合曲线等问题。
import matplotlib.pyplot as plt
#这行代码是导入Python的matplotlib库中的pyplot模块，并将其命名为plt。matplotlib.pyplot模块提供了类似于Matlab命令样式的接口，用于绘制各种静态、动态或交互式的图表，
#如折线图、散点图、柱状图、等高线图、3D图等等。此处我们将其命名为plt是为了方便在代码中调用其函数和方法，避免重复输入长度较长的模块名。
# %matplotlib inline

# %% [markdown]
# * ps: numpy.poly1d([1,2,3])  生成  $1x^2+2x^1+3x^0$*

# %%
# 目标函数
def real_func(x):               #定义一个名为real_func（）的函数，参数为x
    return np.sin(2*np.pi*x)    #将参数x的值代入，返回np.sin（2*np.pi*x）的计算结果

# 多项式
def fit_func(p, x):             #定义一个名为fit_func（）的函数，参数为p和x
    f = np.poly1d(p)            #根据p的值生成多项式
    return f(x)                 #将参数x的值带入上面生成的多项式，并返回结果

# 残差
def residuals_func(p, x, y):    #定义一个名为residuals_func（）的函数，参数为p、x和y
    ret = fit_func(p, x) - y    #将多项式的结果与y相减得到残差
    return ret                  #将残差值返回

# %%
# 十个点
x = np.linspace(0, 1, 10)
#使用了numpy库中的linspace函数，在指定区间内生成等间隔的一维数组，并将其赋值给变量x。
#在0到1之间生成十个均匀分布的数
x_points = np.linspace(0, 1, 1000)
# 加上正态分布噪音的目标函数的值
y_ = real_func(x)
y = [np.random.normal(0, 0.1) + y1 for y1 in y_]
#使用了numpy库中random模块下normal函数，用于从指定平均值和标准差的正态分布中随机取样
#np.random.normal(0, 0.1) 的作用是生成一个均值为0、标准差为0.1的正态分布随机数，代表当前观测值的随机误差；然后将这个随机误差加到 y1 中，得到新的带有噪声的观测值。
#在for循环中，通过y1来迭代y_中的每个元素（将y_中的每个元素依次赋值给y1）
#在每次迭代时都将[np.random.normal(0, 0.1) + y1]作为一个元素添加到y的末尾。


def fitting(M=0):                   #函数定义，函数名为fitting，参数默认为M=0
    """
    M    为 多项式的次数
    """
    # 随机初始化多项式参数
    p_init = np.random.rand(M + 1)  #生成长度为M+1的随机数数组，每个元素都是从0到1之间的随机实数
    # 最小二乘法
    p_lsq = leastsq(residuals_func, p_init, args=(x, y))
    #调用leastsq函数并将返回值存储到p_lsq变量中。p_lsq是一个含有两个数组的元组，第一个数组包含了最优的拟合参数（使残差平方和最小化的参数），第二个数组代表协方差矩阵，衡量了拟合参数之间的相关性，并告诉我们每个参数的不确定程度。
    #在leastsq的三个参数中，p_init和args传递到残差函数中
    print('Fitting Parameters:', p_lsq[0])  #输出第一个数组

    # 可视化
    plt.plot(x_points, real_func(x_points), label='real')
    #x_points包含了想要在x轴上绘制的做有点
    #real是指定曲线的标签，用于区分曲线
    plt.plot(x_points, fit_func(p_lsq[0], x_points), label='fitted curve')
    plt.plot(x, y, 'bo', label='noise')
    #bo中，b代表蓝色（blue），o代表圆形符号，组合在一起就是使用蓝色圆圈来绘制散点图。
    plt.legend()
    #自动识别所有的曲线和label，并在plot中相应添加legend标签
    return p_lsq

# %% [markdown]
# ### M=0

# %%
# M=0
p_lsq_0 = fitting(M=0)
# Out:
# Fitting Parameters: [0.0907056]

# %% [markdown]
# ### M=1

# %%
# M=1
p_lsq_1 = fitting(M=1)
# Out:
# Fitting Parameters: [-1.34392115  0.76266617]

# %% [markdown]
# ### M=3

# %%
# M=3
p_lsq_3 = fitting(M=3)
# Out:
# Fitting Parameters: [ 2.23337582e+01 -3.35854636e+01  1.14518467e+01 -2.19318828e-02]

# %% [markdown]
# ### M=9

# %%
# M=9
p_lsq_9 = fitting(M=9)
# Out:
# Fitting Parameters: [-7.33204733e+03  4.14259180e+04 -9.57218557e+04  1.18206430e+05
#  -8.50924343e+04  3.63708728e+04 -8.91981045e+03  1.10832989e+03
#  -4.53000535e+01  5.26426809e-03]

# %% [markdown]
# 当M=9时，多项式曲线通过了每个数据点，但是造成了过拟合

# %% [markdown]
# ### 正则化

# %% [markdown]
# 结果显示过拟合， 引入正则化项(regularizer)，降低过拟合
#
# $Q(x)=\sum_{i=1}^n(h(x_i)-y_i)^2+\lambda||w||^2$。
#
# 回归问题中，损失函数是平方损失，正则化可以是参数向量的L2范数,也可以是L1范数。
#
# - L1: regularization\*abs(p)
#
# - L2: 0.5 \* regularization \* np.square(p)

# %%
regularization = 0.0001


def residuals_func_regularization(p, x, y):
    ret = fit_func(p, x) - y
    ret = np.append(ret,
                    np.sqrt(0.5 * regularization * np.square(p)))  # L2范数作为正则化项
    #np.square(p)计算p数组中每个元素的平方
    #np.sqrt进行开方
    #np.append将第二个参数所生成的一维数组添加到第一个参数ret数组中
    return ret

# %%
# 最小二乘法,加正则化项
p_init = np.random.rand(9 + 1)  #随机初始化多项式参数
p_lsq_regularization = leastsq(
    residuals_func_regularization, p_init, args=(x, y))

# %%
plt.plot(x_points, real_func(x_points), label='real')                           #目标曲线
plt.plot(x_points, fit_func(p_lsq_9[0], x_points), label='fitted curve')        #拟合曲线
plt.plot(                                                                       #添加正则化之后的曲线
    x_points,
    fit_func(p_lsq_regularization[0], x_points),
    label='regularization')

plt.plot(x, y, 'bo', label='noise')
#bo中，b代表蓝色（blue），o代表圆形符号，组合在一起就是使用蓝色圆圈来绘制散点图。
plt.legend()   #

# %% [markdown]
# ## 第1章统计学习方法概论-习题
# **撰写人：**胡锐锋-天国之影-Relph
#
# **github地址：**https://github.com/datawhalechina/statistical-learning-method-solutions-manual
#
# ### 习题1.1
# &emsp;&emsp;说明伯努利模型的极大似然估计以及贝叶斯估计中的统计学习方法三要素。伯努利模型是定义在取值为0与1的随机变量上的概率分布。假设观测到伯努利模型$n$次独立的数据生成结果，其中$k$次的结果为1，这时可以用极大似然估计或贝叶斯估计来估计结果为1的概率。
#
# **解答：**

# %% [markdown]
# 伯努利模型的极大似然估计以及贝叶斯估计中的**统计学习方法三要素**如下：
# 1. **极大似然估计**
# **模型：** $\mathcal{F}=\{f|f_p(x)=p^x(1-p)^{(1-x)}\}$
# **策略：** 最大化似然函数
# **算法：** $\displaystyle \mathop{\arg\min}_{p} L(p)= \mathop{\arg\min}_{p} \binom{n}{k}p^k(1-p)^{(n-k)}$
# 2. **贝叶斯估计**
# **模型：** $\mathcal{F}=\{f|f_p(x)=p^x(1-p)^{(1-x)}\}$
# **策略：** 求参数期望
# **算法：**
# $$\begin{aligned}  E_\pi\big[p \big| y_1,\cdots,y_n\big]
# & = {\int_0^1}p\pi (p|y_1,\cdots,y_n) dp \\
# & = {\int_0^1} p\frac{f_D(y_1,\cdots,y_n|p)\pi(p)}{\int_{\Omega}f_D(y_1,\cdots,y_n|p)\pi(p)dp}dp \\
# & = {\int_0^1}\frac{p^{k+1}(1-p)^{(n-k)}}{\int_0^1 p^k(1-p)^{(n-k)}dp}dp
# \end{aligned}$$
#
# **伯努利模型的极大似然估计：**
# 定义$P(Y=1)$概率为$p$，可得似然函数为：$$L(p)=f_D(y_1,y_2,\cdots,y_n|\theta)=\binom{n}{k}p^k(1-p)^{(n-k)}$$方程两边同时对$p$求导，则：$$\begin{aligned}
# 0 & = \binom{n}{k}[kp^{k-1}(1-p)^{(n-k)}-(n-k)p^k(1-p)^{(n-k-1)}]\\
# & = \binom{n}{k}[p^{(k-1)}(1-p)^{(n-k-1)}(m-kp)]
# \end{aligned}$$可解出$p$的值为$p=0,p=1,p=k/n$，显然$\displaystyle P(Y=1)=p=\frac{k}{n}$
#
# **伯努利模型的贝叶斯估计：**
# 定义$P(Y=1)$概率为$p$，$p$在$[0,1]$之间的取值是等概率的，因此先验概率密度函数$\pi(p) = 1$，可得似然函数为： $$L(p)=f_D(y_1,y_2,\cdots,y_n|\theta)=\binom{n}{k}p^k(1-p)^{(n-k)}$$
# 根据似然函数和先验概率密度函数，可以求解$p$的条件概率密度函数：$$\begin{aligned}\pi(p|y_1,\cdots,y_n)&=\frac{f_D(y_1,\cdots,y_n|p)\pi(p)}{\int_{\Omega}f_D(y_1,\cdots,y_n|p)\pi(p)dp}\\
# &=\frac{p^k(1-p)^{(n-k)}}{\int_0^1p^k(1-p)^{(n-k)}dp}\\
# &=\frac{p^k(1-p)^{(n-k)}}{B(k+1,n-k+1)}
# \end{aligned}$$所以$p$的期望为：$$\begin{aligned}
# E_\pi[p|y_1,\cdots,y_n]&={\int}p\pi(p|y_1,\cdots,y_n)dp \\
# & = {\int_0^1}\frac{p^{(k+1)}(1-p)^{(n-k)}}{B(k+1,n-k+1)}dp \\
# & = \frac{B(k+2,n-k+1)}{B(k+1,n-k+1)}\\
# & = \frac{k+1}{n+2}
# \end{aligned}$$
# $\therefore \displaystyle P(Y=1)=\frac{k+1}{n+2}$

# %% [markdown]
# ### 习题1.2
# &emsp;&emsp;通过经验风险最小化推导极大似然估计。证明模型是条件概率分布，当损失函数是对数损失函数时，经验风险最小化等价于极大似然估计。
#
# **解答：**
#
# 假设模型的条件概率分布是$P_{\theta}(Y|X)$，现推导当损失函数是对数损失函数时，极大似然估计等价于经验风险最小化。
# 极大似然估计的似然函数为：$$L(\theta)=\prod_D P_{\theta}(Y|X)$$两边取对数：$$\ln L(\theta) = \sum_D \ln P_{\theta}(Y|X) \\
# \mathop{\arg \max}_{\theta} \sum_D \ln P_{\theta}(Y|X) = \mathop{\arg \min}_{\theta} \sum_D (- \ln P_{\theta}(Y|X))$$
# 反之，经验风险最小化等价于极大似然估计，亦可通过经验风险最小化推导极大似然估计。

# %% [markdown]
# ----
# 参考代码：https://github.com/wzyonggege/statistical-learning-method
#
# 本文代码更新地址：https://github.com/fengdu78/lihang-code
#
# 习题解答：https://github.com/datawhalechina/statistical-learning-method-solutions-manual
#
# 中文注释制作：机器学习初学者公众号：ID:ai-start-com
#
# 配置环境：python 3.5+
#
# 代码全部测试通过。
# ![gongzhong](../gongzhong.jpg)
